# %%
import sys
import pandas as pd
import requests
from pathlib import Path

# %%
print(sys.executable)
print(pd.__version__)
print(requests.__version__)
print(Path.cwd())
# Out:
# C:\Users\graha\anaconda3\envs\value-screener\python.exe
# 3.0.3
# 2.34.2
# C:\Users\graha\Documents\Data_Projects\value-investing-research-system\notebooks
